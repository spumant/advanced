# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import time
import re, pip
# Out:
# d:\IDE\Anaconda\A\envs\fproject\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
import os  # 修改环境设置

# 算法/损失/评估指标等
import sklearn
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import KFold, cross_validate

# 优化器
from bayes_opt import BayesianOptimization

import hyperopt
from hyperopt import hp, fmin, tpe, Trials, partial
from hyperopt.early_stop import no_progress_loss

import optuna

# %%
data = pd.read_csv('../data/House Price/train_encode.csv', index_col=0)
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %% [markdown]
# # 基于Bayes_Opt实现GP优化

# %%
def bayesopt_object(n_estimators, max_depth, max_features, min_impurity_decrease):
    # 定义评估器
    # 需要调整的超参数等于目标函数的输入，不需要调整的超参数则直接等于固定值
    # 默认参数输入一定是浮点数，因此需要套上int函数处理成整数
    reg = RFR(
        n_estimators=int(n_estimators),
        max_depth=int(max_depth),
        max_features=int(max_features),
        min_impurity_decrease=min_impurity_decrease,
        random_state=1412,
        verbose=False,
        n_jobs=-1,
    )

    # 定义损失的输出，输出负均方根误差（-RMSE）
    # 注意，交叉验证需要使用数据，但我们不能让数据x,y成为目标函数的输入
    cv = KFold(n_splits=5, shuffle=True, random_state=1412)
    validation_loss = cross_validate(
        reg,
        x,
        y,
        scoring='neg_root_mean_squared_error',
        cv=cv,
        verbose=False,
        n_jobs=-1,
        error_score='raise',
        # 如果交叉验证中的算法执行报错，则告诉我们错误的理由
    )
    # 交叉验证输出的评估指标是负根均方误差，因此本来就是负的损失
    # 目标函数可直接输出该损失的均值
    return np.mean(validation_loss['test_score'])

# %%
param_grid_simple = {
    'n_estimators': (80, 100),
    'max_depth': (10, 25),
    'max_features': (10, 20),
    'min_impurity_decrease': (0, 1),
}

# %%
def param_bayes_opt(init_points, n_iter):
    # 定义优化器，先实例化优化器
    opt = BayesianOptimization(bayesopt_object, param_grid_simple, random_state=1412)
    opt.maximize(init_points=init_points, n_iter=n_iter)  # 抽取多少个初始观测值  # 一共观测/迭代多少次

    # 优化完成，取出最佳参数与最佳分数
    params_best = opt.max['params']
    score_best = opt.max['target']

    # 打印最佳参数与最佳分数
    print(
        "\n",
        "\n",
        "best params: ",
        params_best,
        "\n",
        "\n",
        "best cvscore: ",
        score_best,
    )

    return params_best, score_best

# %%
def bayes_opt_validation(params_best):
    reg = RFR(
        n_estimators=int(params_best['n_estimators']),
        max_depth=int(params_best['max_depth']),
        max_features=int(params_best['max_features']),
        min_impurity_decrease=params_best['min_impurity_decrease'],
        random_state=1412,
        verbose=False,
        n_jobs=-1,
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=1412)
    validation_loss = cross_validate(
        reg,
        x,
        y,
        scoring='neg_root_mean_squared_error',
        cv=cv,
        verbose=False,
        n_jobs=-1,
    )
    return np.mean(validation_loss['test_score'])

# %%
start = time.time()
params_best, score_best = param_bayes_opt(20, 280)  # 初始看20个观测值，后面迭代280次
print(f'It takes {(time.time() - start) / 60} minutes')
validation_score = bayes_opt_validation(params_best)
print("\n", "\n", "validation_score: ", validation_score)
# Out:
# | 300       | -2.872e+0 | 12.45     | 19.04     | 1.0       | 94.09     |
# =========================================================================
#
#
#  best params:  {'max_depth': 24.287280695519435, 'max_features': 14.199279251850534, 'min_impurity_decrease': 0.0, 'n_estimators': 92.49390178792292}
#
#  best cvscore:  -28589.59825568999
# It takes 10.037673203150431 minutes
#
#
#  validation_score:  -28589.59825568999

# %% [markdown]
# # 基于HyperOpt实现TPE优化

# %%
def hyperopt_objective(params):
    # 定义评估器
    # 需要搜索的参数需要从输入的字典中索引出来
    # 不需要搜索的参数，可以是设置好的某个值
    # 在需要整数的参数前调整参数类型
    reg = RFR(
        n_estimators=int(params['n_estimators']),
        max_depth=int(params['max_depth']),
        max_features=int(params['max_features']),
        min_impurity_decrease=params['min_impurity_decrease'],
        random_state=1412,
        verbose=False,
        n_jobs=-1,
    )
    # 交叉验证
    cv = KFold(n_splits=5, shuffle=True, random_state=1412)
    validation_loss = cross_validate(
        reg,
        x,
        y,
        scoring='neg_root_mean_squared_error',
        cv=cv,
        verbose=False,
        n_jobs=-1,
        error_score='raise',
    )
    return np.mean(abs(validation_loss['test_score']))

# %%
param_grid_simple = {
    'n_estimators': hp.quniform('n_estimators', 80, 100, 1),
    'max_depth': hp.quniform('max_depth', 10, 25, 1),
    'max_features': hp.quniform("max_features", 10, 20, 1),
    'min_impurity_decrease': hp.quniform('min_impurity_decrease', 0, 5, 1),
}

# %%
def param_hyperopt(max_evals=100):
    # 保存迭代过程
    trials = Trials()

    # 设置提前停止
    early_stop_fn = no_progress_loss(100)

    # 定义代理模型
    params_best = fmin(
        hyperopt_objective,
        space=param_grid_simple,
        algo=tpe.suggest,  # 代理模型
        max_evals=max_evals,  # 允许的迭代次数
        verbose=True,
        trials=trials,
        early_stop_fn=early_stop_fn,
    )

    print('\n', '\n', "best params:", params_best, '\n')
    return params_best, trials

# %%
def hyperopt_validation(params):
    reg = RFR(
        n_estimators=int(params['n_estimators']),
        max_depth=int(params['max_depth']),
        max_features=int(params['max_features']),
        min_impurity_decrease=params['min_impurity_decrease'],
        random_state=1412,
        verbose=False,
        n_jobs=-1,
    )
    cv = KFold(n_splits=5, shuffle=True, random_state=1412)
    validation_loss = cross_validate(
        reg,
        x,
        y,
        scoring='neg_root_mean_squared_error',
        cv=cv,
        verbose=False,
        n_jobs=-1,
    )
    return np.mean(abs(validation_loss['test_score']))

# %%
params_best, trials = param_hyperopt(30)
# Out:
# 100%|██████████| 30/30 [00:56<00:00,  1.89s/trial, best loss: 28696.954308211716]
#
#
#  best params: {'max_depth': 12.0, 'max_features': 19.0, 'min_impurity_decrease': 2.0, 'n_estimators': 98.0}

# %%
params_best, trials = param_hyperopt(100)
# Out:
# 100%|██████████| 100/100 [02:29<00:00,  1.49s/trial, best loss: 28416.043696810833]
#
#
#  best params: {'max_depth': 22.0, 'max_features': 14.0, 'min_impurity_decrease': 0.0, 'n_estimators': 96.0}

# %%
params_best, trials = param_hyperopt(300)
# Out:
#  51%|█████     | 152/300 [03:29<03:24,  1.38s/trial, best loss: 28398.017337226145]
#
#
#  best params: {'max_depth': 22.0, 'max_features': 14.0, 'min_impurity_decrease': 0.0, 'n_estimators': 83.0}

# %%
hyperopt_validation(params_best)
# Out:
# 28398.017337226145

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 29419.223485937313, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [0],
#     'max_features': [0],
#     'min_impurity_decrease': [0],
#     'n_estimators': [0]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 34, 182000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 35, 361000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 29415.812458628225, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [1],
#     'max_features': [1],
#     'min_impurity_decrease': [1],
#     'n_estimators': [1]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 35, 368000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 36, 714000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 29294.16427342027, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [2],
#     'max_features': [2],
#     'min_impurity_decrease': [2],
#     'n_estimators': [2]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 36, 719000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 38, 394000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 28911.670792589877, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [3],
#     'max_features': [3],
#     'min_impurity_decrease': [3],
#     'n_estimators': [3]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 38, 399000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 40, 35000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 28923.60005746285, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [4],
#     'max_features': [4],
#     'min_impurity_decrease': [4],
#     'n_estimators': [4]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 40, 40000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 41, 398000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 29593.3182144319, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [5],
#     'max_features': [5],
#     'min_impurity_decrease': [5],
#     'n_estimators': [5]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 41, 403000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 42, 560000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 28876.526916334067, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [6],
#     'max_features': [6],
#     'min_impurity_decrease': [6],
#     'n_estimators': [6]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 42, 566000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 44, 253000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 29418.01430490084, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [7],
#     'max_features': [7],
#     'min_impurity_decrease': [7],
#     'n_estimators': [7]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 44, 259000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 45, 365000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 29070.76694628942, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [8],
#     'max_features': [8],
#     'min_impurity_decrease': [8],
#     'n_estimators': [8]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 45, 372000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 46, 884000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 29411.826839318917, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [9],
#     'max_features': [9],
#     'min_impurity_decrease': [9],
#     'n_estimators': [9]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 46, 891000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 48, 8000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': 29086.55090886464, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [10],
#     'max_features': [10],
#     'min_impurity_decrease': [10],
#     'n_estimators': [10]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 48, 14000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 49, 392000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': 29703.751758255577, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [11],
#     'max_features': [11],
#     'min_impurity_decrease': [11],
#     'n_estimators': [11]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 49, 398000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 50, 559000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': 29721.99055857993, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [12],
#     'max_features': [12],
#     'min_impurity_decrease': [12],
#     'n_estimators': [12]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 50, 566000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 51, 739000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': 28830.978641494305, 'status': 'ok'},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [13],
#     'max_features': [13],
#     'min_impurity_decrease': [13],
#     'n_estimators': [13]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 51, 748000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 53, 538000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': 29038.418670638486, 'status': 'ok'},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [14],
#     'max_features': [14],
#     'min_impurity_decrease': [14],
#     'n_estimators': [14]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 53, 544000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 55, 171000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': 29544.16440918027, 'status': 'ok'},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [15],
#     'max_features': [15],
#     'min_impurity_decrease': [15],
#     'n_estimators': [15]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 55, 176000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 56, 435000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': 29287.719541128074, 'status': 'ok'},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [16],
#     'max_features': [16],
#     'min_impurity_decrease': [16],
#     'n_estimators': [16]},
#    'vals': {'max_depth': [10.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 56, 441000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 57, 286000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': 28922.537394973806, 'status': 'ok'},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [17],
#     'max_features': [17],
#     'min_impurity_decrease': [17],
#     'n_estimators': [17]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 57, 292000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 40, 58, 963000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': 28703.360702044483, 'status': 'ok'},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [18],
#     'max_features': [18],
#     'min_impurity_decrease': [18],
#     'n_estimators': [18]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 40, 58, 968000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 0, 400000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': 29390.074334885907, 'status': 'ok'},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [19],
#     'max_features': [19],
#     'min_impurity_decrease': [19],
#     'n_estimators': [19]},
#    'vals': {'max_depth': [13.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 0, 406000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 1, 452000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': 28878.94031928825, 'status': 'ok'},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [20],
#     'max_features': [20],
#     'min_impurity_decrease': [20],
#     'n_estimators': [20]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 1, 476000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 3, 481000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': 29050.914925016834, 'status': 'ok'},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [21],
#     'max_features': [21],
#     'min_impurity_decrease': [21],
#     'n_estimators': [21]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [20.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 3, 497000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 5, 62000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': 28620.359743952227, 'status': 'ok'},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [22],
#     'max_features': [22],
#     'min_impurity_decrease': [22],
#     'n_estimators': [22]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 5, 85000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 6, 684000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': 28878.65091675911, 'status': 'ok'},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [23],
#     'max_features': [23],
#     'min_impurity_decrease': [23],
#     'n_estimators': [23]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 6, 706000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 8, 270000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': 29014.77004831169, 'status': 'ok'},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [24],
#     'max_features': [24],
#     'min_impurity_decrease': [24],
#     'n_estimators': [24]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 8, 291000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 9, 919000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': 29487.87139034178, 'status': 'ok'},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [25],
#     'max_features': [25],
#     'min_impurity_decrease': [25],
#     'n_estimators': [25]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 9, 941000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 11, 494000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': 29205.341591011296, 'status': 'ok'},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [26],
#     'max_features': [26],
#     'min_impurity_decrease': [26],
#     'n_estimators': [26]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 11, 519000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 12, 865000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': 29298.428777430665, 'status': 'ok'},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [27],
#     'max_features': [27],
#     'min_impurity_decrease': [27],
#     'n_estimators': [27]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [10.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 12, 884000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 13, 817000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': 29465.527783688427, 'status': 'ok'},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [28],
#     'max_features': [28],
#     'min_impurity_decrease': [28],
#     'n_estimators': [28]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 13, 839000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 15, 78000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': 28998.938388193743, 'status': 'ok'},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [29],
#     'max_features': [29],
#     'min_impurity_decrease': [29],
#     'n_estimators': [29]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 15, 100000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 16, 667000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': 29146.797967424256, 'status': 'ok'},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [30],
#     'max_features': [30],
#     'min_impurity_decrease': [30],
#     'n_estimators': [30]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 16, 692000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 18, 243000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': 29303.809372073923, 'status': 'ok'},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [31],
#     'max_features': [31],
#     'min_impurity_decrease': [31],
#     'n_estimators': [31]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 18, 265000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 19, 872000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': 28969.44394209375, 'status': 'ok'},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [32],
#     'max_features': [32],
#     'min_impurity_decrease': [32],
#     'n_estimators': [32]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 19, 893000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 21, 197000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': 29409.424052264145, 'status': 'ok'},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [33],
#     'max_features': [33],
#     'min_impurity_decrease': [33],
#     'n_estimators': [33]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 21, 218000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 22, 844000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': 29575.651382505534, 'status': 'ok'},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [34],
#     'max_features': [34],
#     'min_impurity_decrease': [34],
#     'n_estimators': [34]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 22, 865000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 24, 77000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': 29076.184410879116, 'status': 'ok'},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [35],
#     'max_features': [35],
#     'min_impurity_decrease': [35],
#     'n_estimators': [35]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 24, 106000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 25, 554000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': 28965.972285599564, 'status': 'ok'},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [36],
#     'max_features': [36],
#     'min_impurity_decrease': [36],
#     'n_estimators': [36]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 25, 576000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 27, 104000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': 29127.866791238117, 'status': 'ok'},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [37],
#     'max_features': [37],
#     'min_impurity_decrease': [37],
#     'n_estimators': [37]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 27, 127000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 28, 600000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': 29210.218439446056, 'status': 'ok'},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [38],
#     'max_features': [38],
#     'min_impurity_decrease': [38],
#     'n_estimators': [38]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 28, 625000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 30, 96000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': 28826.892339775786, 'status': 'ok'},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [39],
#     'max_features': [39],
#     'min_impurity_decrease': [39],
#     'n_estimators': [39]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [18.0],
#     'min_impurity_decrease': [5.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 30, 117000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 31, 688000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': 29677.76116436494, 'status': 'ok'},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [40],
#     'max_features': [40],
#     'min_impurity_decrease': [40],
#     'n_estimators': [40]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 31, 713000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 32, 931000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': 29030.6145005377, 'status': 'ok'},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [41],
#     'max_features': [41],
#     'min_impurity_decrease': [41],
#     'n_estimators': [41]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 32, 956000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 34, 653000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': 29243.29229179395, 'status': 'ok'},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [42],
#     'max_features': [42],
#     'min_impurity_decrease': [42],
#     'n_estimators': [42]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 34, 677000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 35, 924000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': 28541.893480783514, 'status': 'ok'},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [43],
#     'max_features': [43],
#     'min_impurity_decrease': [43],
#     'n_estimators': [43]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 35, 951000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 37, 247000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': 29553.184847428267, 'status': 'ok'},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [44],
#     'max_features': [44],
#     'min_impurity_decrease': [44],
#     'n_estimators': [44]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 37, 272000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 38, 490000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': 28566.203723907638, 'status': 'ok'},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [45],
#     'max_features': [45],
#     'min_impurity_decrease': [45],
#     'n_estimators': [45]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 38, 515000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 39, 911000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': 29104.323859412514, 'status': 'ok'},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [46],
#     'max_features': [46],
#     'min_impurity_decrease': [46],
#     'n_estimators': [46]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 39, 947000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 41, 226000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': 29099.26075123822, 'status': 'ok'},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [47],
#     'max_features': [47],
#     'min_impurity_decrease': [47],
#     'n_estimators': [47]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 41, 252000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 42, 348000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': 29865.821582081302, 'status': 'ok'},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [48],
#     'max_features': [48],
#     'min_impurity_decrease': [48],
#     'n_estimators': [48]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 42, 376000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 43, 605000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': 29312.032707014714, 'status': 'ok'},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [49],
#     'max_features': [49],
#     'min_impurity_decrease': [49],
#     'n_estimators': [49]},
#    'vals': {'max_depth': [12.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 43, 630000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 44, 777000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': 29525.588757921672, 'status': 'ok'},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [50],
#     'max_features': [50],
#     'min_impurity_decrease': [50],
#     'n_estimators': [50]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 44, 810000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 46, 260000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': 28398.017337226145, 'status': 'ok'},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [51],
#     'max_features': [51],
#     'min_impurity_decrease': [51],
#     'n_estimators': [51]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 46, 292000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 47, 492000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': 29115.983624680714, 'status': 'ok'},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [52],
#     'max_features': [52],
#     'min_impurity_decrease': [52],
#     'n_estimators': [52]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 47, 524000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 48, 674000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': 29036.06695716909, 'status': 'ok'},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [53],
#     'max_features': [53],
#     'min_impurity_decrease': [53],
#     'n_estimators': [53]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 48, 701000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 49, 999000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': 28933.86079190867, 'status': 'ok'},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [54],
#     'max_features': [54],
#     'min_impurity_decrease': [54],
#     'n_estimators': [54]},
#    'vals': {'max_depth': [15.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 50, 26000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 51, 316000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': 29284.167136381875, 'status': 'ok'},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [55],
#     'max_features': [55],
#     'min_impurity_decrease': [55],
#     'n_estimators': [55]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [10.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 51, 352000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 52, 597000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': 29644.257940132025, 'status': 'ok'},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [56],
#     'max_features': [56],
#     'min_impurity_decrease': [56],
#     'n_estimators': [56]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 52, 623000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 53, 771000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': 29445.46651942777, 'status': 'ok'},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [57],
#     'max_features': [57],
#     'min_impurity_decrease': [57],
#     'n_estimators': [57]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 53, 799000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 55, 263000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': 29526.7957306136, 'status': 'ok'},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [58],
#     'max_features': [58],
#     'min_impurity_decrease': [58],
#     'n_estimators': [58]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [91.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 55, 291000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 56, 608000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': 29643.05617793153, 'status': 'ok'},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [59],
#     'max_features': [59],
#     'min_impurity_decrease': [59],
#     'n_estimators': [59]},
#    'vals': {'max_depth': [11.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 56, 635000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 57, 648000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': 28717.475855156885, 'status': 'ok'},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [60],
#     'max_features': [60],
#     'min_impurity_decrease': [60],
#     'n_estimators': [60]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 57, 682000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 41, 59, 170000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': 29049.507054207304, 'status': 'ok'},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [61],
#     'max_features': [61],
#     'min_impurity_decrease': [61],
#     'n_estimators': [61]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 41, 59, 199000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 0, 626000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': 29136.116024308943, 'status': 'ok'},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [62],
#     'max_features': [62],
#     'min_impurity_decrease': [62],
#     'n_estimators': [62]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 0, 657000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 1, 851000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': 29821.89727055612, 'status': 'ok'},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [63],
#     'max_features': [63],
#     'min_impurity_decrease': [63],
#     'n_estimators': [63]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [10.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 1, 883000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 3, 40000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': 29710.836998934974, 'status': 'ok'},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [64],
#     'max_features': [64],
#     'min_impurity_decrease': [64],
#     'n_estimators': [64]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 3, 76000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 4, 98000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': 28566.203723907638, 'status': 'ok'},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [65],
#     'max_features': [65],
#     'min_impurity_decrease': [65],
#     'n_estimators': [65]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 4, 136000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 5, 511000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': 29063.151184175695, 'status': 'ok'},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [66],
#     'max_features': [66],
#     'min_impurity_decrease': [66],
#     'n_estimators': [66]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [88.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 5, 538000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 6, 795000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': 29100.175348859724, 'status': 'ok'},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [67],
#     'max_features': [67],
#     'min_impurity_decrease': [67],
#     'n_estimators': [67]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 6, 827000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 8, 67000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': 28529.74588375524, 'status': 'ok'},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [68],
#     'max_features': [68],
#     'min_impurity_decrease': [68],
#     'n_estimators': [68]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 8, 123000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 9, 513000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': 28691.319783860257, 'status': 'ok'},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [69],
#     'max_features': [69],
#     'min_impurity_decrease': [69],
#     'n_estimators': [69]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [87.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 9, 545000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 10, 948000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': 29193.356220964994, 'status': 'ok'},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [70],
#     'max_features': [70],
#     'min_impurity_decrease': [70],
#     'n_estimators': [70]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [90.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 10, 992000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 12, 465000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': 29153.837784028816, 'status': 'ok'},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [71],
#     'max_features': [71],
#     'min_impurity_decrease': [71],
#     'n_estimators': [71]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 12, 497000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 13, 802000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': 29104.397274332576, 'status': 'ok'},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [72],
#     'max_features': [72],
#     'min_impurity_decrease': [72],
#     'n_estimators': [72]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 13, 836000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 15, 300000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': 28673.46696761161, 'status': 'ok'},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [73],
#     'max_features': [73],
#     'min_impurity_decrease': [73],
#     'n_estimators': [73]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 15, 336000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 16, 687000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': 29359.680067834015, 'status': 'ok'},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [74],
#     'max_features': [74],
#     'min_impurity_decrease': [74],
#     'n_estimators': [74]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 16, 727000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 17, 911000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': 29441.04535804225, 'status': 'ok'},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [75],
#     'max_features': [75],
#     'min_impurity_decrease': [75],
#     'n_estimators': [75]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 42, 17, 943000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 42, 19, 50000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': 29290.71562880101, 'status': 'ok'},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [76],
#     'max_features': [76],
#     'min_impurity_decrease': [76],
#     'n_estimators': [76]},
# ...
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 27, 12000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 28, 401000)},
#  {'state': 2,
#   'tid': 127,
#   'spec': None,
#   'result': {'loss': 29073.31349051514, 'status': 'ok'},
#   'misc': {'tid': 127,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [127],
#     'max_features': [127],
#     'min_impurity_decrease': [127],
#     'n_estimators': [127]},
#    'vals': {'max_depth': [16.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 28, 450000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 29, 742000)},
#  {'state': 2,
#   'tid': 128,
#   'spec': None,
#   'result': {'loss': 29121.2104692979, 'status': 'ok'},
#   'misc': {'tid': 128,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [128],
#     'max_features': [128],
#     'min_impurity_decrease': [128],
#     'n_estimators': [128]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [4.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 29, 790000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 31, 300000)},
#  {'state': 2,
#   'tid': 129,
#   'spec': None,
#   'result': {'loss': 29084.20622569105, 'status': 'ok'},
#   'misc': {'tid': 129,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [129],
#     'max_features': [129],
#     'min_impurity_decrease': [129],
#     'n_estimators': [129]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [100.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 31, 357000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 32, 899000)},
#  {'state': 2,
#   'tid': 130,
#   'spec': None,
#   'result': {'loss': 29754.14642143624, 'status': 'ok'},
#   'misc': {'tid': 130,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [130],
#     'max_features': [130],
#     'min_impurity_decrease': [130],
#     'n_estimators': [130]},
#    'vals': {'max_depth': [19.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [93.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 32, 955000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 34, 382000)},
#  {'state': 2,
#   'tid': 131,
#   'spec': None,
#   'result': {'loss': 28679.667715972213, 'status': 'ok'},
#   'misc': {'tid': 131,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [131],
#     'max_features': [131],
#     'min_impurity_decrease': [131],
#     'n_estimators': [131]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 34, 430000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 35, 937000)},
#  {'state': 2,
#   'tid': 132,
#   'spec': None,
#   'result': {'loss': 29713.336753056523, 'status': 'ok'},
#   'misc': {'tid': 132,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [132],
#     'max_features': [132],
#     'min_impurity_decrease': [132],
#     'n_estimators': [132]},
#    'vals': {'max_depth': [18.0],
#     'max_features': [11.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 35, 986000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 37, 240000)},
#  {'state': 2,
#   'tid': 133,
#   'spec': None,
#   'result': {'loss': 29091.013379818276, 'status': 'ok'},
#   'misc': {'tid': 133,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [133],
#     'max_features': [133],
#     'min_impurity_decrease': [133],
#     'n_estimators': [133]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [97.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 37, 292000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 38, 822000)},
#  {'state': 2,
#   'tid': 134,
#   'spec': None,
#   'result': {'loss': 29382.50138783796, 'status': 'ok'},
#   'misc': {'tid': 134,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [134],
#     'max_features': [134],
#     'min_impurity_decrease': [134],
#     'n_estimators': [134]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 38, 875000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 40, 455000)},
#  {'state': 2,
#   'tid': 135,
#   'spec': None,
#   'result': {'loss': 29298.660643557727, 'status': 'ok'},
#   'misc': {'tid': 135,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [135],
#     'max_features': [135],
#     'min_impurity_decrease': [135],
#     'n_estimators': [135]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [98.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 40, 508000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 41, 940000)},
#  {'state': 2,
#   'tid': 136,
#   'spec': None,
#   'result': {'loss': 29283.26156224125, 'status': 'ok'},
#   'misc': {'tid': 136,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [136],
#     'max_features': [136],
#     'min_impurity_decrease': [136],
#     'n_estimators': [136]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [17.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [95.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 41, 988000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 43, 446000)},
#  {'state': 2,
#   'tid': 137,
#   'spec': None,
#   'result': {'loss': 29672.289694297662, 'status': 'ok'},
#   'misc': {'tid': 137,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [137],
#     'max_features': [137],
#     'min_impurity_decrease': [137],
#     'n_estimators': [137]},
#    'vals': {'max_depth': [14.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [92.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 43, 512000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 44, 937000)},
#  {'state': 2,
#   'tid': 138,
#   'spec': None,
#   'result': {'loss': 28900.575592632835, 'status': 'ok'},
#   'misc': {'tid': 138,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [138],
#     'max_features': [138],
#     'min_impurity_decrease': [138],
#     'n_estimators': [138]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [16.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [89.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 44, 990000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 46, 503000)},
#  {'state': 2,
#   'tid': 139,
#   'spec': None,
#   'result': {'loss': 28519.58609898605, 'status': 'ok'},
#   'misc': {'tid': 139,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [139],
#     'max_features': [139],
#     'min_impurity_decrease': [139],
#     'n_estimators': [139]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 46, 552000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 47, 738000)},
#  {'state': 2,
#   'tid': 140,
#   'spec': None,
#   'result': {'loss': 29070.34098556756, 'status': 'ok'},
#   'misc': {'tid': 140,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [140],
#     'max_features': [140],
#     'min_impurity_decrease': [140],
#     'n_estimators': [140]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [19.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [80.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 47, 791000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 49, 125000)},
#  {'state': 2,
#   'tid': 141,
#   'spec': None,
#   'result': {'loss': 29261.993848489154, 'status': 'ok'},
#   'misc': {'tid': 141,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [141],
#     'max_features': [141],
#     'min_impurity_decrease': [141],
#     'n_estimators': [141]},
#    'vals': {'max_depth': [17.0],
#     'max_features': [12.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [99.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 49, 181000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 50, 590000)},
#  {'state': 2,
#   'tid': 142,
#   'spec': None,
#   'result': {'loss': 29083.053190914605, 'status': 'ok'},
#   'misc': {'tid': 142,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [142],
#     'max_features': [142],
#     'min_impurity_decrease': [142],
#     'n_estimators': [142]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 50, 645000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 51, 766000)},
#  {'state': 2,
#   'tid': 143,
#   'spec': None,
#   'result': {'loss': 29703.85897612641, 'status': 'ok'},
#   'misc': {'tid': 143,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [143],
#     'max_features': [143],
#     'min_impurity_decrease': [143],
#     'n_estimators': [143]},
#    'vals': {'max_depth': [20.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [94.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 51, 824000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 53, 294000)},
#  {'state': 2,
#   'tid': 144,
#   'spec': None,
#   'result': {'loss': 29097.125453240336, 'status': 'ok'},
#   'misc': {'tid': 144,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [144],
#     'max_features': [144],
#     'min_impurity_decrease': [144],
#     'n_estimators': [144]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [96.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 53, 362000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 54, 811000)},
#  {'state': 2,
#   'tid': 145,
#   'spec': None,
#   'result': {'loss': 28572.45555246949, 'status': 'ok'},
#   'misc': {'tid': 145,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [145],
#     'max_features': [145],
#     'min_impurity_decrease': [145],
#     'n_estimators': [145]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [82.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 54, 866000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 56, 175000)},
#  {'state': 2,
#   'tid': 146,
#   'spec': None,
#   'result': {'loss': 29115.983624680714, 'status': 'ok'},
#   'misc': {'tid': 146,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [146],
#     'max_features': [146],
#     'min_impurity_decrease': [146],
#     'n_estimators': [146]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [83.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 56, 228000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 57, 336000)},
#  {'state': 2,
#   'tid': 147,
#   'spec': None,
#   'result': {'loss': 28630.940655441875, 'status': 'ok'},
#   'misc': {'tid': 147,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [147],
#     'max_features': [147],
#     'min_impurity_decrease': [147],
#     'n_estimators': [147]},
#    'vals': {'max_depth': [24.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [81.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 57, 391000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 43, 58, 640000)},
#  {'state': 2,
#   'tid': 148,
#   'spec': None,
#   'result': {'loss': 29248.822002944817, 'status': 'ok'},
#   'misc': {'tid': 148,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [148],
#     'max_features': [148],
#     'min_impurity_decrease': [148],
#     'n_estimators': [148]},
#    'vals': {'max_depth': [23.0],
#     'max_features': [15.0],
#     'min_impurity_decrease': [0.0],
#     'n_estimators': [86.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 43, 58, 696000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 44, 0, 141000)},
#  {'state': 2,
#   'tid': 149,
#   'spec': None,
#   'result': {'loss': 28935.51994724379, 'status': 'ok'},
#   'misc': {'tid': 149,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [149],
#     'max_features': [149],
#     'min_impurity_decrease': [149],
#     'n_estimators': [149]},
#    'vals': {'max_depth': [25.0],
#     'max_features': [13.0],
#     'min_impurity_decrease': [3.0],
#     'n_estimators': [84.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 44, 0, 191000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 44, 1, 379000)},
#  {'state': 2,
#   'tid': 150,
#   'spec': None,
#   'result': {'loss': 28421.389469559355, 'status': 'ok'},
#   'misc': {'tid': 150,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [150],
#     'max_features': [150],
#     'min_impurity_decrease': [150],
#     'n_estimators': [150]},
#    'vals': {'max_depth': [22.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [1.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2023, 8, 5, 14, 44, 1, 442000),
#   'refresh_time': datetime.datetime(2023, 8, 5, 14, 44, 2, 626000)},
#  {'state': 2,
#   'tid': 151,
#   'spec': None,
#   'result': {'loss': 29125.074111805112, 'status': 'ok'},
#   'misc': {'tid': 151,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'max_depth': [151],
#     'max_features': [151],
#     'min_impurity_decrease': [151],
#     'n_estimators': [151]},
#    'vals': {'max_depth': [21.0],
#     'max_features': [14.0],
#     'min_impurity_decrease': [2.0],
#     'n_estimators': [85.0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(
#  29382.50138783796,
#  29298.660643557727,
#  29283.26156224125,
#  29672.289694297662,
#  28900.575592632835,
#  28519.58609898605,
#  29070.34098556756,
#  29261.993848489154,
#  29083.053190914605,
#  29703.85897612641,
#  29097.125453240336,
#  28572.45555246949,
#  29115.983624680714,
#  28630.940655441875,
#  29248.822002944817,
#  28935.51994724379,
#  28421.389469559355,
#  29125.074111805112]

# %% [markdown]
# # 基于Optuna实现多种贝叶斯优化

# %%
def optuna_objective(trial):
    # 定义参数空间
    n_estimators = trial.suggest_int("n_estimators", 80, 100, 1)  # 整数型，(参数名称，下界，上界，步长)
    max_depth = trial.suggest_int("max_depth", 10, 25, 1)
    max_features = trial.suggest_int("max_features", 10, 20, 1)
    # max_features = trial.suggest_categorical("max_features",["log2","sqrt","auto"]) #字符型
    min_impurity_decrease = trial.suggest_int("min_impurity_decrease", 0, 5, 1)
    # min_impurity_decrease = trial.suggest_float("min_impurity_decrease",0,5,log=False) #浮点型

    # 定义评估器
    # 需要优化的参数由上述参数空间决定
    # 不需要优化的参数则直接填写具体值
    reg = RFR(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        min_impurity_decrease=min_impurity_decrease,
        random_state=1412,
        verbose=False,
        n_jobs=-1,
    )

    # 交叉验证过程，输出负均方根误差(-RMSE)
    # optuna同时支持最大化和最小化，因此如果输出-RMSE，则选择最大化
    # 如果选择输出RMSE，则选择最小化
    cv = KFold(n_splits=5, shuffle=True, random_state=1412)
    validation_loss = cross_validate(
        reg,
        x,
        y,
        scoring="neg_root_mean_squared_error",
        cv=cv,  # 交叉验证模式
        verbose=False,  # 是否打印进程
        n_jobs=-1,  # 线程数
        error_score='raise',
    )
    # 最终输出RMSE
    return np.mean(abs(validation_loss["test_score"]))

# %%
def optimizer_optuna(n_trials, algo):
    # 定义使用TPE或者GP
    if algo == 'TPE':
        algo = optuna.samplers.TPESampler(n_startup_trials=10, n_ei_candidates=24)
    elif algo == 'GP':
        from optuna.integration import SkoptSampler
        import skopt

        algo = SkoptSampler(
            skopt_kwargs={
                'base_estimator': 'GP',  # 选择高斯过程
                'n_initial_points': 10,  # 初始观测点10个
                'acq_func': 'EI',  # 选择的采集函数为EI，期望增量
            }
        )
    # 实际优化过程，首先实例优化器
    study = optuna.create_study(sampler=algo, direction='minimize')

    # 开始优化，n_trials为允许的最大迭代次数
    # 由于参数空间已经在目标函数中定义好，因此不需要输入参数空间
    study.optimize(
        optuna_objective,  # 目标函数
        n_trials=n_trials,  # 最大迭代次数（包括最初的观测值的）
        show_progress_bar=True,  # 要不要展示进度条呀？
    )

    # 可以直接从优化好的对象study中调用优化的结果
    # 打印最佳参数与最佳损失值
    print(
        "\n",
        "\n",
        "best params: ",
        study.best_trial.params,
        "\n",
        "\n",
        "best score: ",
        study.best_trial.values,
        "\n",
    )

    return study.best_trial.params, study.best_trial.values

# %%
import warnings
warnings.filterwarnings('ignore', message='The objective has been evaluated at this point before.')

# %%
best_params, best_score = optimizer_optuna(10, "GP")  # 默认打印迭代过程
# Out:
# [I 2023-08-06 20:17:50,823] A new study created in memory with name: no-name-d1b1a6c9-2ede-421d-8bf2-7439ce164700
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2023-08-06 20:17:57,897] Trial 0 finished with value: 29125.40685413478 and parameters: {'n_estimators': 92, 'max_depth': 13, 'max_features': 13, 'min_impurity_decrease': 4}. Best is trial 0 with value: 29125.40685413478.
# [I 2023-08-06 20:18:01,692] Trial 1 finished with value: 29670.426073132032 and parameters: {'n_estimators': 96, 'max_depth': 22, 'max_features': 12, 'min_impurity_decrease': 5}. Best is trial 0 with value: 29125.40685413478.
# [I 2023-08-06 20:18:03,335] Trial 2 finished with value: 29035.387047404794 and parameters: {'n_estimators': 85, 'max_depth': 17, 'max_features': 20, 'min_impurity_decrease': 2}. Best is trial 2 with value: 29035.387047404794.
# [I 2023-08-06 20:18:04,760] Trial 3 finished with value: 29683.967345799338 and parameters: {'n_estimators': 82, 'max_depth': 19, 'max_features': 12, 'min_impurity_decrease': 3}. Best is trial 2 with value: 29035.387047404794.
# [I 2023-08-06 20:18:06,326] Trial 4 finished with value: 29388.331966901158 and parameters: {'n_estimators': 89, 'max_depth': 21, 'max_features': 11, 'min_impurity_decrease': 4}. Best is trial 2 with value: 29035.387047404794.
# [I 2023-08-06 20:18:07,916] Trial 5 finished with value: 29585.207695649267 and parameters: {'n_estimators': 99, 'max_depth': 18, 'max_features': 12, 'min_impurity_decrease': 2}. Best is trial 2 with value: 29035.387047404794.
# [I 2023-08-06 20:18:09,752] Trial 6 finished with value: 29132.00630760425 and parameters: {'n_estimators': 95, 'max_depth': 17, 'max_features': 18, 'min_impurity_decrease': 1}. Best is trial 2 with value: 29035.387047404794.
# [I 2023-08-06 20:18:11,205] Trial 7 finished with value: 28787.614883313276 and parameters: {'n_estimators': 84, 'max_depth': 19, 'max_features': 17, 'min_impurity_decrease': 3}. Best is trial 7 with value: 28787.614883313276.
# [I 2023-08-06 20:18:12,926] Trial 8 finished with value: 29103.47299863695 and parameters: {'n_estimators': 96, 'max_depth': 20, 'max_features': 11, 'min_impurity_decrease': 1}. Best is trial 7 with value: 28787.614883313276.
# [I 2023-08-06 20:18:14,481] Trial 9 finished with value: 29049.424711949163 and parameters: {'n_estimators': 91, 'max_depth': 25, 'max_features': 13, 'min_impurity_decrease': 0}. Best is trial 7 with value: 28787.614883313276.
#
#
#  best params:  {'n_estimators': 84, 'max_depth': 19, 'max_features': 17, 'min_impurity_decrease': 3}
#
#  best score:  [28787.614883313276]

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR)  # 关闭自动打印的info，只显示进度条
# optuna.logging.set_verbosity(optuna.logging.INFO)
best_params, best_score = optimizer_optuna(300, "TPE")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
#
#  best params:  {'n_estimators': 89, 'max_depth': 22, 'max_features': 14, 'min_impurity_decrease': 0}
#
#  best score:  [28346.672687223065]

# %%
best_params, best_score = optimizer_optuna(300,"GP")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
#
#  best params:  {'n_estimators': 100, 'max_depth': 22, 'max_features': 14, 'min_impurity_decrease': 0}
#
#  best score:  [28399.470801233365]
